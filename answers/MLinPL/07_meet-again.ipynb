# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# <div class="main-title">
# <h1>Let's meet again!</h1>
# </div>

# %% [markdown]
# ## Contributions
# ### [https://github.com/kraina-ai/srai](https://github.com/kraina-ai/srai)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Discussions and feedback
# ### [https://github.com/kraina-ai/srai/discussions/389](https://github.com/kraina-ai/srai/discussions/389)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # `Geospatial data needs its Hugging Face moment`

# %% [markdown]
# ## Questions?

# %% [markdown]
# # Thank you!
